# %%
from generator import generate
import matplotlib.pyplot as plt

# %%
prods = ["APFELMUSS", "BATTERIEN", "BITTERLEMON", "BOHNEN", "BUTTER", "CHAMPIGNONS", "CHIPS", "DEODORANT"]
probs = [0.1,0.08,0.3,0.3,0.4,0.4,0.5,0.05]
data, pxs = generate(probs,prods)
f, axes = plt.subplots(8,1)
for i in range(len(axes)):
    
    axes[i].plot(data[:,i])
    axes[i].plot(pxs[:,i])
